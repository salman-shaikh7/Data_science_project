# %% [markdown]
# <h1>Agricultural Production Optimization Engine<h1>

# %% [markdown]
# **Problem Statement:** <br>
# Build a predictive Model so as to suggest the most suitable crops to grow based on available climatic and soil conditions.

# %% [markdown]
# STEP1: Importing libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import  seaborn as sns 

import ipywidgets as interact1

# %% [markdown]
# STEP 2: Importing data set

# %%
data=pd.read_csv("C:/Users/SAJAHANG/Desktop/Agriculture production optimization/Crop_recommendation.csv")

# %%
data.shape
# Out:
# (2200, 8)

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
grouped_data=data.groupby('label')

# %%
grouped_data['label'].count()
# Out:
# label
# apple          100
# banana         100
# blackgram      100
# chickpea       100
# coconut        100
# coffee         100
# cotton         100
# grapes         100
# jute           100
# kidneybeans    100
# lentil         100
# maize          100
# mango          100
# mothbeans      100
# mungbean       100
# muskmelon      100
# orange         100
# papaya         100
# pigeonpeas     100
# pomegranate    100
# rice           100
# watermelon     100
# Name: label, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
data.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
list(data.columns)
# Out:
# ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label']

# %%
data[data['label']=='apple'].describe()
# Out:
#                 N           P           K  temperature    humidity  \
# count  100.000000  100.000000  100.000000   100.000000  100.000000
# mean    20.800000  134.220000  199.890000    22.630942   92.333383
# std     11.863704    8.139665    3.320871     0.827404    1.458551
# min      0.000000  120.000000  195.000000    21.036527   90.025751
# 25%     10.000000  126.750000  197.000000    22.163206   90.970127
# 50%     24.000000  136.500000  200.000000    22.628290   92.416541
# 75%     30.000000  141.000000  203.000000    23.344066   93.509252
# max     40.000000  145.000000  205.000000    23.996862   94.920481
#
#                ph    rainfall
# count  100.000000  100.000000
# mean     5.929663  112.654779
# std      0.268932    7.102985
# min      5.514253  100.117344
# 25%      5.705800  106.070135
# 50%      5.885818  112.979230
# 75%      6.135616  118.449546
# max      6.499227  124.983162

# %% [markdown]
# We can analyse condition for apple from above table
# Min Temp required = 21.036527
# Max Temp required = 23.996862
#
#
# In this way we can analyze for all the crops x

# %%
data.describe().rainfall
# Out:
# count    2200.000000
# mean      103.463655
# std        54.958389
# min        20.211267
# 25%        64.551686
# 50%        94.867624
# 75%       124.267508
# max       298.560117
# Name: rainfall, dtype: float64

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
a=data.groupby('label').mean()
a
# Out:
#                   N       P       K  temperature   humidity        ph  \
# label
# apple         20.80  134.22  199.89    22.630942  92.333383  5.929663
# banana       100.23   82.01   50.05    27.376798  80.358123  5.983893
# blackgram     40.02   67.47   19.24    29.973340  65.118426  7.133952
# chickpea      40.09   67.79   79.92    18.872847  16.860439  7.336957
# coconut       21.98   16.93   30.59    27.409892  94.844272  5.976562
# coffee       101.20   28.74   29.94    25.540477  58.869846  6.790308
# cotton       117.77   46.24   19.56    23.988958  79.843474  6.912675
# grapes        23.18  132.53  200.11    23.849575  81.875228  6.025937
# jute          78.40   46.86   39.99    24.958376  79.639864  6.732778
# kidneybeans   20.75   67.54   20.05    20.115085  21.605357  5.749411
# lentil        18.77   68.36   19.41    24.509052  64.804785  6.927932
# maize         77.76   48.44   19.79    22.389204  65.092249  6.245190
# ...

# %%
data
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
sns.set_style('darkgrid')
sns.set(font_scale=1.3)
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
sns.histplot(data['N'],bins=100,kde=True);

# %%
sns.histplot(data['P'],bins=100,kde=True);

# %%
sns.histplot(data['K'],bins=100,kde=True);

# %%
sns.histplot(data['humidity'],bins=100,kde=True);

# %%
sns.histplot(data['ph'],bins=100,kde=True);

# %%
sns.histplot(data['rainfall'],bins=100,kde=True);

# %%
sns.histplot(data['temperature'],bins=100);

# %%
sns.pairplot(data=data);

# %%
data
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
Model=LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
x=data.drop('label', axis=1)

# %%
x
# Out:
#         N   P   K  temperature   humidity        ph    rainfall
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340
# ...   ...  ..  ..          ...        ...       ...         ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041
#
# [2200 rows x 7 columns]

# %%
y=data['label']

# %%
y
# Out:
# 0         rice
# 1         rice
# 2         rice
# 3         rice
# 4         rice
#          ...
# 2195    coffee
# 2196    coffee
# 2197    coffee
# 2198    coffee
# 2199    coffee
# Name: label, Length: 2200, dtype: object

# %%
x_train.head()
# Out:
#         N    P    K  temperature   humidity        ph    rainfall
# 1975  134   56   18    23.808346  83.919026  6.691268   70.973583
# 1287   29  122  196    41.948657  81.155952  5.638328   73.068630
# 760    25   68   19    29.399827  64.255107  7.108450   67.476773
# 267    41   69   82    20.023815  16.632945  6.715587   68.978065
# 2007   70   43   40    24.355641  88.803910  6.176860  169.116803

# %%
Model.fit(x_train,y_train)
# Out:
# c:\Program Files\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = Model.predict(x_test)

# %%
Model.score(x_test,y_test)
# Out:
# 0.9672727272727273
